# %% [markdown]
# # Data Collation
#
# > How do books become classics?
# - toc: true
# - badges: true
# - comments: true
# - categories: [canon]

# %% [markdown]
# ## How can I access a huge dataset?
#
# Some of my data, specifically the goodreads dataset and the Amazon sales ranks, are in huge JSON files that need to be converted to an appropriate ontology for a book. Loading this all into memory at once will crash my computer.

# %%
import pandas as pd

pd.set_option("display.max_columns", None)

# %%
books_json = pd.read_json('/run/media/mage/INDESTRUCTIBLESLIME/Replaceable/datasets/goodreads/downloads/goodreads_books.json', lines=True, chunksize=200)

# %%
for chunk in books_json:
    break

# %%
chunk

# %%
chunk.loc[395]

# %% [markdown]
# I can move through it in chunks and save each piece as a separate .csv file, then process that data more easily. And in the process, I might as well filter out any books I definitely don't want -- like ebooks.

# %%
chunk['is_ebook'].value_counts()

# %%
# %rm records/*

# %%
from tqdm import tqdm

# %%
books_json = pd.read_json('/run/media/mage/INDESTRUCTIBLESLIME/Replaceable/datasets/goodreads/downloads/goodreads_books.json', lines=True, chunksize=100000)

# %%
for i, chunk in tqdm(enumerate(books_json)):
    filtered_chunk = chunk[chunk['is_ebook'] == 'false']
    filtered_chunk.to_csv(f'records/goodreads_books_{str(i).zfill(4)}.csv')
#     print(i, len(filtered_chunk))

# %% [markdown]
# Over **TWO MILLION BOOKS** in this dataset! How exciting.
#
# Now we need to do something with them. Specifically, it would be smart to look at a sample chunk and clean it up, then run that process across all the chunks. Then hopefully it will be small enough to hold in memory at once, and we can start doing transforms.

# %%
df = pd.read_csv('records/goodreads_books_0007.csv')

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(df, title="Pandas Profiling Report")

# %%
profile.to_widgets()

# %% [markdown]
# Takeaways from the profile:
#
# Columns to remove:
# - with more than 50% missing values:
#     ```
#     edition_information
#     kindle_asin
#     ````
# - with constant values:
#     ```
#     country_code
#     is_ebook
#     ````
#
# The `asin` values are mostly missing, but we're going to need those to compare to Amazon data later so keep that column.
#
# Lots of missing values for `isbn` and `isbn13`, maybe they will cancel each other out?
#
# The `average_rating` is around 3.8, with a standard deviation around 0.53. A 4.57 rating is 95th percentile, whcih might be important to know later. Almost no books have 0, 1, or 2 ratings, so the 5th percentile is right at 3.00.
#
# Formats: still have audiobooks in here. Probably better to clean them out actively and leave weird one-off data in there, rtather than restrict only to known book formats.
#
# The `publication_month` might be useful, but not `publication_day` because too mny values are missing. Unfortunately `publication_year` is missing 15% of it's
#
# I am not really qualified to comment on th popularity of non-english books, but the `lang` field is missing a lot of values, so I'll keep all those books until I find a compelling reason to leave them out. But should probably filter out all the non-English-lang rows..
#
# Only about half of books have a `similar_books` measurement, but that seems like ti will be really useful so I'll keep them all.
#
# The `num_pages` distribution looks good, just skewed by a few multi-volume sets. That's fine for our purposes.
#
# It looks like `title_without_series` actually includes the series name anyway, so let's just drop that entirely.
#
# After that much cleanup, the dataset should be a little smaller and then we can really explore the whole terrain.

# %%
dropped_df = df.drop(['edition_information','kindle_asin', 'country_code', 'is_ebook', 'publication_day', 'title_without_series'], axis=1)

# %%
langs = [o for o in df['language_code'].value_counts().index if o not in ['eng','en-US','en-GB','en-CA']]

# %%
eng_df = dropped_df[~dropped_df['language_code'].isin(langs)]
len(eng_df)

# %%
formats = ['Audio CD', 'Audiobook', 'Audible Audio', 'Audio', 'audio cd', 'Audio Cassette', 'MP3 CD', 'CD-ROM', 'Podiobook', 'Audio Play', 'MP3', 'audio']

paper_df = eng_df[~eng_df['format'].isin(formats)]

# %%
len(paper_df)

# %%
def clean_df(df):
    
    dropped_df = df.drop(['edition_information','kindle_asin', 'country_code', 'is_ebook', 'publication_day', 'title_without_series'], axis=1)
    eng_df = dropped_df[~dropped_df['language_code'].isin(langs)]
    paper_df = eng_df[~eng_df['format'].isin(formats)]
    return(paper_df)

# %%
cleaned_df = clean_df(df)
len(cleaned_df)

# %% [markdown]
# Seems to work. Let's run it over each one sequentially, appending it to an overall dataframe from inside a context manager

# %% [markdown]
# ## How can I collate the data into an accessible format?

# %%
total_df = pd.DataFrame()

# %%
for i in tqdm(range(24)):
    df = pd.read_csv(f'records/goodreads_books_{str(i).zfill(4)}.csv')
    cleaned_df = clean_df(df)
    print(len(cleaned_df), len(total_df))
    total_df = pd.concat([total_df,cleaned_df], ignore_index=True)

# %%
total_df

# %%
total_df.to_csv('records/cleaned_goodreads_books.csv')

# %% [markdown]
# # Explore

# %% [markdown]
# ## Find top genre for each book

# %%
total_df = pd.read_csv('records/cleaned_goodreads_books.csv')

# %%
total_df
# Out:
#          Unnamed: 0  Unnamed: 0.1        isbn  text_reviews_count      series  \
# 0                 0             0  0312853122                 1.0          []
# 1                 1             2         NaN                 7.0  ['189911']
# 2                 2             3  0743294297              3282.0          []
# 3                 3             4  0850308712                 5.0          []
# 4                 4             5  1599150603                 7.0          []
# ...             ...           ...         ...                 ...         ...
# 1216067     1216067       2360645  0689852959                 1.0          []
# 1216068     1216068       2360647  0373126476                 9.0          []
# 1216069     1216069       2360651  178092870X                 2.0          []
# 1216070     1216070       2360652  0765197456                 6.0          []
# 1216071     1216071       2360653  162378140X                17.0  ['658195']
#
#         language_code                                    popular_shelves  \
# 0                 NaN  [{'count': '3', 'name': 'to-read'}, {'count': ...
# 1                 eng  [{'count': '58', 'name': 'to-read'}, {'count':...
# 2                 eng  [{'count': '7615', 'name': 'to-read'}, {'count...
# 3                 NaN  [{'count': '32', 'name': 'to-read'}, {'count':...
# 4                 NaN  [{'count': '56', 'name': 'to-read'}, {'count':...
# ...               ...                                                ...
# 1216067           NaN  [{'count': '22', 'name': 'to-read'}, {'count':...
# 1216068           NaN  [{'count': '78', 'name': 'to-read'}, {'count':...
# 1216069           eng  [{'count': '702', 'name': 'to-read'}, {'count'...
# 1216070           NaN  [{'count': '37', 'name': 'to-read'}, {'count':...
# 1216071           eng  [{'count': '56', 'name': 'to-read'}, {'count':...
#
#                asin  average_rating  \
# 0               NaN            4.00
# 1        B00071IKUY            4.03
# 2               NaN            3.49
# 3               NaN            3.40
# 4               NaN            4.13
# ...             ...             ...
# 1216067         NaN            4.36
# 1216068         NaN            3.42
# 1216069         NaN            3.50
# 1216070         NaN            4.00
# 1216071         NaN            4.37
#
#                                              similar_books  \
# 0                                                       []
# 1        ['19997', '828466', '1569323', '425389', '1176...
# 2        ['6604176', '6054190', '2285777', '82641', '75...
# 3                                                       []
# 4                                                       []
# ...                                                    ...
# 1216067                                                 []
# 1216068  ['2200344', '695337', '10333421', '1934240', '...
# 1216069  ['12064253', '25017213', '571796', '27306126',...
# 1216070                                                 []
# 1216071  ['23562786', '13548289', '26094541', '20570173...
#
#                                                description     format  \
# 0                                                      NaN  Paperback
# 1        Omnibus book club edition containing the Ladie...  Hardcover
# 2        Addie Downs and Valerie Adler were eight when ...  Hardcover
# 3                                                      NaN        NaN
# 4        Relates in vigorous prose the tale of Aeneas, ...  Paperback
# ...                                                    ...        ...
# 1216067  One of the most popular series ever published ...  Paperback
# 1216068  Blackmailed into marriage to save her family, ...  Paperback
# 1216069  Sir Arthur Conan Doyle is brought back to life...  Paperback
# 1216070  Gathers poems by William Blake, Emily Bronte, ...  Hardcover
# 1216071  Volume One contains: "Claimed," "Tainted," and...  Paperback
#
#                                                       link  \
# 0        https://www.goodreads.com/book/show/5333265-w-...
# 1        https://www.goodreads.com/book/show/7327624-th...
# 2        https://www.goodreads.com/book/show/6066819-be...
# 3        https://www.goodreads.com/book/show/287140.Run...
# 4        https://www.goodreads.com/book/show/287141.The...
# ...                                                    ...
# 1216067  https://www.goodreads.com/book/show/331839.Jac...
# 1216068  https://www.goodreads.com/book/show/2685097-th...
# 1216069  https://www.goodreads.com/book/show/26168430-s...
# 1216070  https://www.goodreads.com/book/show/2342551.Th...
# 1216071  https://www.goodreads.com/book/show/22017381-1...
#
#                                                    authors  \
# 0                    [{'author_id': '604031', 'role': ''}]
# 1                     [{'author_id': '10333', 'role': ''}]
# 2                      [{'author_id': '9212', 'role': ''}]
# 3                    [{'author_id': '149918', 'role': ''}]
# 4                   [{'author_id': '3041852', 'role': ''}]
# ...                                                    ...
# 1216067  [{'author_id': '10681', 'role': ''}, {'author_...
# 1216068              [{'author_id': '319441', 'role': ''}]
# 1216069  [{'author_id': '2448', 'role': ''}, {'author_i...
# 1216070         [{'author_id': '82312', 'role': 'Editor'}]
# 1216071             [{'author_id': '7789809', 'role': ''}]
#
#                       publisher  num_pages         isbn13  publication_month  \
# 0            St. Martin's Press      256.0  9780312853129                9.0
# 1        Nelson Doubleday, Inc.      600.0            NaN                NaN
# 2                   Atria Books      368.0  9780743294294                7.0
# 3                           NaN        NaN  9780850308716                NaN
# 4          Yesterday's Classics      162.0  9781599150604                9.0
# ...                         ...        ...            ...                ...
# 1216067                 Aladdin      176.0  9780689852954                9.0
# 1216068               Harlequin      192.0  9780373126477                7.0
# 1216069           MX Publishing      148.0  9781780928708                8.0
# 1216070    Smithmark Publishers       96.0  9780765197450                8.0
# 1216071      Guerrilla Wordfare      306.0  9781623781408                4.0
#
#          publication_year                                                url  \
# 0                  1984.0  https://www.goodreads.com/book/show/5333265-w-...
# 1                  1987.0  https://www.goodreads.com/book/show/7327624-th...
# 2                  2009.0  https://www.goodreads.com/book/show/6066819-be...
# 3                     NaN  https://www.goodreads.com/book/show/287140.Run...
# 4                  2006.0  https://www.goodreads.com/book/show/287141.The...
# ...                   ...                                                ...
# 1216067            2002.0  https://www.goodreads.com/book/show/331839.Jac...
# 1216068            2007.0  https://www.goodreads.com/book/show/2685097-th...
# 1216069            2015.0  https://www.goodreads.com/book/show/26168430-s...
# 1216070            1996.0  https://www.goodreads.com/book/show/2342551.Th...
# 1216071            2014.0  https://www.goodreads.com/book/show/22017381-1...
#
#                                                  image_url   book_id  \
# 0        https://images.gr-assets.com/books/1310220028m...   5333265
# 1        https://images.gr-assets.com/books/1304100136m...   7327624
# 2        https://s.gr-assets.com/assets/nophoto/book/11...   6066819
# 3        https://images.gr-assets.com/books/1413219371m...    287140
# 4        https://s.gr-assets.com/assets/nophoto/book/11...    287141
# ...                                                    ...       ...
# 1216067  https://s.gr-assets.com/assets/nophoto/book/11...    331839
# 1216068  https://s.gr-assets.com/assets/nophoto/book/11...   2685097
# 1216069  https://images.gr-assets.com/books/1440592011m...  26168430
# 1216070  https://s.gr-assets.com/assets/nophoto/book/11...   2342551
# 1216071  https://images.gr-assets.com/books/1398621236m...  22017381
#
#          ratings_count     work_id  \
# 0                  3.0   5400751.0
# 1                140.0   8948723.0
# 2              51184.0   6243154.0
# 3                 15.0    278577.0
# 4                 46.0    278578.0
# ...                ...         ...
# 1216067           18.0  25313618.0
# 1216068          112.0   2710420.0
# 1216069            6.0  46130263.0
# 1216070           36.0   2349247.0
# 1216071           70.0  41332799.0
#
#                                                      title
# 0                              W.C. Fields: A Life on Film
# 1        The Unschooled Wizard (Sun Wolf and Starhawk, ...
# 2                                     Best Friends Forever
# 3        Runic Astrology: Starcraft and Timekeeping in ...
# 4                            The Aeneid for Boys and Girls
# ...                                                    ...
# 1216067     Jacqueline Kennedy Onassis: Friend of the Arts
# 1216068                   The Spaniard's Blackmailed Bride
# 1216069                Sherlock Holmes and the July Crisis
# 1216070           The Children's Classic Poetry Collection
# 1216071          101 Nights: Volume One (101 Nights, #1-3)
#
# [1216072 rows x 25 columns]

# %%
def get_genre(shelf_dict):
    if len(shelf_dict) > 0:
        top = [o for o in shelf_dict if o['name'] not in ['to-read', 'currently-reading', 'kindle', 'non-fiction', 'nonfiction']]
        if len(top):
            return(top[0]['name'])
        else:
            return('NONFIC')
    return('UNK')

# %%
g = (get_genre(eval(o)) for o in total_df['popular_shelves'])
total_df['top_genre'] = pd.Series(g, dtype='unicode')

# %%
total_df.tail()
# Out:
#          Unnamed: 0  Unnamed: 0.1        isbn  text_reviews_count      series  \
# 1216067     1216067       2360645  0689852959                 1.0          []
# 1216068     1216068       2360647  0373126476                 9.0          []
# 1216069     1216069       2360651  178092870X                 2.0          []
# 1216070     1216070       2360652  0765197456                 6.0          []
# 1216071     1216071       2360653  162378140X                17.0  ['658195']
#
#         language_code                                    popular_shelves asin  \
# 1216067           NaN  [{'count': '22', 'name': 'to-read'}, {'count':...  NaN
# 1216068           NaN  [{'count': '78', 'name': 'to-read'}, {'count':...  NaN
# 1216069           eng  [{'count': '702', 'name': 'to-read'}, {'count'...  NaN
# 1216070           NaN  [{'count': '37', 'name': 'to-read'}, {'count':...  NaN
# 1216071           eng  [{'count': '56', 'name': 'to-read'}, {'count':...  NaN
#
#          average_rating                                      similar_books  \
# 1216067            4.36                                                 []
# 1216068            3.42  ['2200344', '695337', '10333421', '1934240', '...
# 1216069            3.50  ['12064253', '25017213', '571796', '27306126',...
# 1216070            4.00                                                 []
# 1216071            4.37  ['23562786', '13548289', '26094541', '20570173...
#
#                                                description     format  \
# 1216067  One of the most popular series ever published ...  Paperback
# 1216068  Blackmailed into marriage to save her family, ...  Paperback
# 1216069  Sir Arthur Conan Doyle is brought back to life...  Paperback
# 1216070  Gathers poems by William Blake, Emily Bronte, ...  Hardcover
# 1216071  Volume One contains: "Claimed," "Tainted," and...  Paperback
#
#                                                       link  \
# 1216067  https://www.goodreads.com/book/show/331839.Jac...
# 1216068  https://www.goodreads.com/book/show/2685097-th...
# 1216069  https://www.goodreads.com/book/show/26168430-s...
# 1216070  https://www.goodreads.com/book/show/2342551.Th...
# 1216071  https://www.goodreads.com/book/show/22017381-1...
#
#                                                    authors  \
# 1216067  [{'author_id': '10681', 'role': ''}, {'author_...
# 1216068              [{'author_id': '319441', 'role': ''}]
# 1216069  [{'author_id': '2448', 'role': ''}, {'author_i...
# 1216070         [{'author_id': '82312', 'role': 'Editor'}]
# 1216071             [{'author_id': '7789809', 'role': ''}]
#
#                     publisher  num_pages         isbn13  publication_month  \
# 1216067               Aladdin      176.0  9780689852954                9.0
# 1216068             Harlequin      192.0  9780373126477                7.0
# 1216069         MX Publishing      148.0  9781780928708                8.0
# 1216070  Smithmark Publishers       96.0  9780765197450                8.0
# 1216071    Guerrilla Wordfare      306.0  9781623781408                4.0
#
#          publication_year                                                url  \
# 1216067            2002.0  https://www.goodreads.com/book/show/331839.Jac...
# 1216068            2007.0  https://www.goodreads.com/book/show/2685097-th...
# 1216069            2015.0  https://www.goodreads.com/book/show/26168430-s...
# 1216070            1996.0  https://www.goodreads.com/book/show/2342551.Th...
# 1216071            2014.0  https://www.goodreads.com/book/show/22017381-1...
#
#                                                  image_url   book_id  \
# 1216067  https://s.gr-assets.com/assets/nophoto/book/11...    331839
# 1216068  https://s.gr-assets.com/assets/nophoto/book/11...   2685097
# 1216069  https://images.gr-assets.com/books/1440592011m...  26168430
# 1216070  https://s.gr-assets.com/assets/nophoto/book/11...   2342551
# 1216071  https://images.gr-assets.com/books/1398621236m...  22017381
#
#          ratings_count     work_id  \
# 1216067           18.0  25313618.0
# 1216068          112.0   2710420.0
# 1216069            6.0  46130263.0
# 1216070           36.0   2349247.0
# 1216071           70.0  41332799.0
#
#                                                   title  top_genre
# 1216067  Jacqueline Kennedy Onassis: Friend of the Arts  biography
# 1216068                The Spaniard's Blackmailed Bride  harlequin
# 1216069             Sherlock Holmes and the July Crisis    mystery
# 1216070        The Children's Classic Poetry Collection     poetry
# 1216071       101 Nights: Volume One (101 Nights, #1-3)    erotica

# %%
total_df.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1)
# Out:
#                isbn  text_reviews_count      series language_code  \
# 0        0312853122                 1.0          []           NaN
# 1               NaN                 7.0  ['189911']           eng
# 2        0743294297              3282.0          []           eng
# 3        0850308712                 5.0          []           NaN
# 4        1599150603                 7.0          []           NaN
# ...             ...                 ...         ...           ...
# 1216067  0689852959                 1.0          []           NaN
# 1216068  0373126476                 9.0          []           NaN
# 1216069  178092870X                 2.0          []           eng
# 1216070  0765197456                 6.0          []           NaN
# 1216071  162378140X                17.0  ['658195']           eng
#
#                                            popular_shelves        asin  \
# 0        [{'count': '3', 'name': 'to-read'}, {'count': ...         NaN
# 1        [{'count': '58', 'name': 'to-read'}, {'count':...  B00071IKUY
# 2        [{'count': '7615', 'name': 'to-read'}, {'count...         NaN
# 3        [{'count': '32', 'name': 'to-read'}, {'count':...         NaN
# 4        [{'count': '56', 'name': 'to-read'}, {'count':...         NaN
# ...                                                    ...         ...
# 1216067  [{'count': '22', 'name': 'to-read'}, {'count':...         NaN
# 1216068  [{'count': '78', 'name': 'to-read'}, {'count':...         NaN
# 1216069  [{'count': '702', 'name': 'to-read'}, {'count'...         NaN
# 1216070  [{'count': '37', 'name': 'to-read'}, {'count':...         NaN
# 1216071  [{'count': '56', 'name': 'to-read'}, {'count':...         NaN
#
#          average_rating                                      similar_books  \
# 0                  4.00                                                 []
# 1                  4.03  ['19997', '828466', '1569323', '425389', '1176...
# 2                  3.49  ['6604176', '6054190', '2285777', '82641', '75...
# 3                  3.40                                                 []
# 4                  4.13                                                 []
# ...                 ...                                                ...
# 1216067            4.36                                                 []
# 1216068            3.42  ['2200344', '695337', '10333421', '1934240', '...
# 1216069            3.50  ['12064253', '25017213', '571796', '27306126',...
# 1216070            4.00                                                 []
# 1216071            4.37  ['23562786', '13548289', '26094541', '20570173...
#
#                                                description     format  \
# 0                                                      NaN  Paperback
# 1        Omnibus book club edition containing the Ladie...  Hardcover
# 2        Addie Downs and Valerie Adler were eight when ...  Hardcover
# 3                                                      NaN        NaN
# 4        Relates in vigorous prose the tale of Aeneas, ...  Paperback
# ...                                                    ...        ...
# 1216067  One of the most popular series ever published ...  Paperback
# 1216068  Blackmailed into marriage to save her family, ...  Paperback
# 1216069  Sir Arthur Conan Doyle is brought back to life...  Paperback
# 1216070  Gathers poems by William Blake, Emily Bronte, ...  Hardcover
# 1216071  Volume One contains: "Claimed," "Tainted," and...  Paperback
#
#                                                       link  \
# 0        https://www.goodreads.com/book/show/5333265-w-...
# 1        https://www.goodreads.com/book/show/7327624-th...
# 2        https://www.goodreads.com/book/show/6066819-be...
# 3        https://www.goodreads.com/book/show/287140.Run...
# 4        https://www.goodreads.com/book/show/287141.The...
# ...                                                    ...
# 1216067  https://www.goodreads.com/book/show/331839.Jac...
# 1216068  https://www.goodreads.com/book/show/2685097-th...
# 1216069  https://www.goodreads.com/book/show/26168430-s...
# 1216070  https://www.goodreads.com/book/show/2342551.Th...
# 1216071  https://www.goodreads.com/book/show/22017381-1...
#
#                                                    authors  \
# 0                    [{'author_id': '604031', 'role': ''}]
# 1                     [{'author_id': '10333', 'role': ''}]
# 2                      [{'author_id': '9212', 'role': ''}]
# 3                    [{'author_id': '149918', 'role': ''}]
# 4                   [{'author_id': '3041852', 'role': ''}]
# ...                                                    ...
# 1216067  [{'author_id': '10681', 'role': ''}, {'author_...
# 1216068              [{'author_id': '319441', 'role': ''}]
# 1216069  [{'author_id': '2448', 'role': ''}, {'author_i...
# 1216070         [{'author_id': '82312', 'role': 'Editor'}]
# 1216071             [{'author_id': '7789809', 'role': ''}]
#
#                       publisher  num_pages         isbn13  publication_month  \
# 0            St. Martin's Press      256.0  9780312853129                9.0
# 1        Nelson Doubleday, Inc.      600.0            NaN                NaN
# 2                   Atria Books      368.0  9780743294294                7.0
# 3                           NaN        NaN  9780850308716                NaN
# 4          Yesterday's Classics      162.0  9781599150604                9.0
# ...                         ...        ...            ...                ...
# 1216067                 Aladdin      176.0  9780689852954                9.0
# 1216068               Harlequin      192.0  9780373126477                7.0
# 1216069           MX Publishing      148.0  9781780928708                8.0
# 1216070    Smithmark Publishers       96.0  9780765197450                8.0
# 1216071      Guerrilla Wordfare      306.0  9781623781408                4.0
#
#          publication_year                                                url  \
# 0                  1984.0  https://www.goodreads.com/book/show/5333265-w-...
# 1                  1987.0  https://www.goodreads.com/book/show/7327624-th...
# 2                  2009.0  https://www.goodreads.com/book/show/6066819-be...
# 3                     NaN  https://www.goodreads.com/book/show/287140.Run...
# 4                  2006.0  https://www.goodreads.com/book/show/287141.The...
# ...                   ...                                                ...
# 1216067            2002.0  https://www.goodreads.com/book/show/331839.Jac...
# 1216068            2007.0  https://www.goodreads.com/book/show/2685097-th...
# 1216069            2015.0  https://www.goodreads.com/book/show/26168430-s...
# 1216070            1996.0  https://www.goodreads.com/book/show/2342551.Th...
# 1216071            2014.0  https://www.goodreads.com/book/show/22017381-1...
#
#                                                  image_url   book_id  \
# 0        https://images.gr-assets.com/books/1310220028m...   5333265
# 1        https://images.gr-assets.com/books/1304100136m...   7327624
# 2        https://s.gr-assets.com/assets/nophoto/book/11...   6066819
# 3        https://images.gr-assets.com/books/1413219371m...    287140
# 4        https://s.gr-assets.com/assets/nophoto/book/11...    287141
# ...                                                    ...       ...
# 1216067  https://s.gr-assets.com/assets/nophoto/book/11...    331839
# 1216068  https://s.gr-assets.com/assets/nophoto/book/11...   2685097
# 1216069  https://images.gr-assets.com/books/1440592011m...  26168430
# 1216070  https://s.gr-assets.com/assets/nophoto/book/11...   2342551
# 1216071  https://images.gr-assets.com/books/1398621236m...  22017381
#
#          ratings_count     work_id  \
# 0                  3.0   5400751.0
# 1                140.0   8948723.0
# 2              51184.0   6243154.0
# 3                 15.0    278577.0
# 4                 46.0    278578.0
# ...                ...         ...
# 1216067           18.0  25313618.0
# 1216068          112.0   2710420.0
# 1216069            6.0  46130263.0
# 1216070           36.0   2349247.0
# 1216071           70.0  41332799.0
#
#                                                      title  top_genre
# 0                              W.C. Fields: A Life on Film          p
# 1        The Unschooled Wizard (Sun Wolf and Starhawk, ...    fantasy
# 2                                     Best Friends Forever  chick-lit
# 3        Runic Astrology: Starcraft and Timekeeping in ...      runes
# 4                            The Aeneid for Boys and Girls    history
# ...                                                    ...        ...
# 1216067     Jacqueline Kennedy Onassis: Friend of the Arts  biography
# 1216068                   The Spaniard's Blackmailed Bride  harlequin
# 1216069                Sherlock Holmes and the July Crisis    mystery
# 1216070           The Children's Classic Poetry Collection     poetry
# 1216071          101 Nights: Volume One (101 Nights, #1-3)    erotica
#
# [1216072 rows x 24 columns]

# %%
total_df.to_csv('records/cleaned_goodreads_books.csv')

# %%
total_df = pd.read_csv('records/cleaned_goodreads_books.csv')

# %% [markdown]
# ## Get author data
#
# It's in a different JSON file, we'll have to copy the data in somehow

# %%
author_df = pd.read_json('/run/media/mage/INDESTRUCTIBLESLIME/Replaceable/datasets/goodreads/downloads/goodreads_book_authors.json', lines=True)

# %%
author_df = author_df.set_index('author_id')

# %%
author_df
# Out:
#            average_rating  text_reviews_count              name  ratings_count
# author_id
# 604031               3.98                   7  Ronald J. Fields             49
# 626222               4.08               28716     Anita Diamant         546796
# 10333                3.92                5075    Barbara Hambly         122118
# 9212                 3.68               36262   Jennifer Weiner         888522
# 149918               3.82                  96     Nigel Pennick           1740
# ...                   ...                 ...               ...            ...
# 197551               4.36                   4     Patty Furbush             11
# 3988103              4.33                   3    Jim Schlinkman              6
# 13464507             4.00                   2        Rich Jolly             18
# 7427847              3.31                   1         sr@ mwrGn             13
# 5401342              3.70                  11    Barry S. Brown             43
#
# [829529 rows x 4 columns]

# %%
total_df['authors']
# Out:
# 0                      [{'author_id': '604031', 'role': ''}]
# 1                       [{'author_id': '10333', 'role': ''}]
# 2                        [{'author_id': '9212', 'role': ''}]
# 3                      [{'author_id': '149918', 'role': ''}]
# 4                     [{'author_id': '3041852', 'role': ''}]
#                                  ...
# 1216067    [{'author_id': '10681', 'role': ''}, {'author_...
# 1216068                [{'author_id': '319441', 'role': ''}]
# 1216069    [{'author_id': '2448', 'role': ''}, {'author_i...
# 1216070           [{'author_id': '82312', 'role': 'Editor'}]
# 1216071               [{'author_id': '7789809', 'role': ''}]
# Name: authors, Length: 1216072, dtype: object

# %%
author_df.loc[604031]
# Out:
# average_rating                    3.98
# text_reviews_count                   7
# name                  Ronald J. Fields
# ratings_count                       49
# Name: 604031, dtype: object

# %%
def get_author(a_list):
    try:
        top = int(eval(a_list)[0]['author_id'])
        return(author_df.loc[top]['name'])
    except IndexError as e:
        print(e)
        return('UNK')

# %%
from tqdm import tqdm

# %%
g = [get_author(a_list) for a_list in tqdm(total_df['authors'])]
# Out:
#   3%|▎         | 31308/1216072 [00:04<02:32, 7771.24it/s]
#
#
#
#
#
#
#
#
#  14%|█▍        | 170558/1216072 [00:22<02:14, 7792.28it/s]A
# list index out of range
#  27%|██▋       | 332791/1216072 [00:42<01:53, 7754.12it/s]
# list index out of range
#  34%|███▍      | 415285/1216072 [00:53<01:42, 7836.99it/s]
# list index out of range
#  35%|███▍      | 423153/1216072 [00:54<01:40, 7882.49it/s]
# list index out of range
#  38%|███▊      | 466594/1216072 [01:00<01:40, 7424.44it/s]
# list index out of range
#  43%|████▎     | 522876/1216072 [01:07<01:29, 7718.93it/s]
# list index out of range
#  47%|████▋     | 577099/1216072 [01:14<01:22, 7752.83it/s]
# list index out of range
#  55%|█████▍    | 663032/1216072 [01:25<01:14, 7387.21it/s]
# list index out of range
#  96%|█████████▌| 1163852/1216072 [02:30<00:06, 7686.75it/s]
# list index out of range
# 100%|██████████| 1216072/1216072 [02:37<00:00, 7721.25it/s]

# %%
total_df['author_name'] = g

# %%
total_df
# Out:
#          Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1        isbn  \
# 0                 0             0               0  0312853122
# 1                 1             1               2         NaN
# 2                 2             2               3  0743294297
# 3                 3             3               4  0850308712
# 4                 4             4               5  1599150603
# ...             ...           ...             ...         ...
# 1216067     1216067       1216067         2360645  0689852959
# 1216068     1216068       1216068         2360647  0373126476
# 1216069     1216069       1216069         2360651  178092870X
# 1216070     1216070       1216070         2360652  0765197456
# 1216071     1216071       1216071         2360653  162378140X
#
#          text_reviews_count      series language_code  \
# 0                       1.0          []           NaN
# 1                       7.0  ['189911']           eng
# 2                    3282.0          []           eng
# 3                       5.0          []           NaN
# 4                       7.0          []           NaN
# ...                     ...         ...           ...
# 1216067                 1.0          []           NaN
# 1216068                 9.0          []           NaN
# 1216069                 2.0          []           eng
# 1216070                 6.0          []           NaN
# 1216071                17.0  ['658195']           eng
#
#                                            popular_shelves        asin  \
# 0        [{'count': '3', 'name': 'to-read'}, {'count': ...         NaN
# 1        [{'count': '58', 'name': 'to-read'}, {'count':...  B00071IKUY
# 2        [{'count': '7615', 'name': 'to-read'}, {'count...         NaN
# 3        [{'count': '32', 'name': 'to-read'}, {'count':...         NaN
# 4        [{'count': '56', 'name': 'to-read'}, {'count':...         NaN
# ...                                                    ...         ...
# 1216067  [{'count': '22', 'name': 'to-read'}, {'count':...         NaN
# 1216068  [{'count': '78', 'name': 'to-read'}, {'count':...         NaN
# 1216069  [{'count': '702', 'name': 'to-read'}, {'count'...         NaN
# 1216070  [{'count': '37', 'name': 'to-read'}, {'count':...         NaN
# 1216071  [{'count': '56', 'name': 'to-read'}, {'count':...         NaN
#
#          average_rating                                      similar_books  \
# 0                  4.00                                                 []
# 1                  4.03  ['19997', '828466', '1569323', '425389', '1176...
# 2                  3.49  ['6604176', '6054190', '2285777', '82641', '75...
# 3                  3.40                                                 []
# 4                  4.13                                                 []
# ...                 ...                                                ...
# 1216067            4.36                                                 []
# 1216068            3.42  ['2200344', '695337', '10333421', '1934240', '...
# 1216069            3.50  ['12064253', '25017213', '571796', '27306126',...
# 1216070            4.00                                                 []
# 1216071            4.37  ['23562786', '13548289', '26094541', '20570173...
#
#                                                description     format  \
# 0                                                      NaN  Paperback
# 1        Omnibus book club edition containing the Ladie...  Hardcover
# 2        Addie Downs and Valerie Adler were eight when ...  Hardcover
# 3                                                      NaN        NaN
# 4        Relates in vigorous prose the tale of Aeneas, ...  Paperback
# ...                                                    ...        ...
# 1216067  One of the most popular series ever published ...  Paperback
# 1216068  Blackmailed into marriage to save her family, ...  Paperback
# 1216069  Sir Arthur Conan Doyle is brought back to life...  Paperback
# 1216070  Gathers poems by William Blake, Emily Bronte, ...  Hardcover
# 1216071  Volume One contains: "Claimed," "Tainted," and...  Paperback
#
#                                                       link  \
# 0        https://www.goodreads.com/book/show/5333265-w-...
# 1        https://www.goodreads.com/book/show/7327624-th...
# 2        https://www.goodreads.com/book/show/6066819-be...
# 3        https://www.goodreads.com/book/show/287140.Run...
# 4        https://www.goodreads.com/book/show/287141.The...
# ...                                                    ...
# 1216067  https://www.goodreads.com/book/show/331839.Jac...
# 1216068  https://www.goodreads.com/book/show/2685097-th...
# 1216069  https://www.goodreads.com/book/show/26168430-s...
# 1216070  https://www.goodreads.com/book/show/2342551.Th...
# 1216071  https://www.goodreads.com/book/show/22017381-1...
#
#                                                    authors  \
# 0                    [{'author_id': '604031', 'role': ''}]
# 1                     [{'author_id': '10333', 'role': ''}]
# 2                      [{'author_id': '9212', 'role': ''}]
# 3                    [{'author_id': '149918', 'role': ''}]
# 4                   [{'author_id': '3041852', 'role': ''}]
# ...                                                    ...
# 1216067  [{'author_id': '10681', 'role': ''}, {'author_...
# 1216068              [{'author_id': '319441', 'role': ''}]
# 1216069  [{'author_id': '2448', 'role': ''}, {'author_i...
# 1216070         [{'author_id': '82312', 'role': 'Editor'}]
# 1216071             [{'author_id': '7789809', 'role': ''}]
#
#                       publisher  num_pages         isbn13  publication_month  \
# 0            St. Martin's Press      256.0  9780312853129                9.0
# 1        Nelson Doubleday, Inc.      600.0            NaN                NaN
# 2                   Atria Books      368.0  9780743294294                7.0
# 3                           NaN        NaN  9780850308716                NaN
# 4          Yesterday's Classics      162.0  9781599150604                9.0
# ...                         ...        ...            ...                ...
# 1216067                 Aladdin      176.0  9780689852954                9.0
# 1216068               Harlequin      192.0  9780373126477                7.0
# 1216069           MX Publishing      148.0  9781780928708                8.0
# 1216070    Smithmark Publishers       96.0  9780765197450                8.0
# 1216071      Guerrilla Wordfare      306.0  9781623781408                4.0
#
#          publication_year                                                url  \
# 0                  1984.0  https://www.goodreads.com/book/show/5333265-w-...
# 1                  1987.0  https://www.goodreads.com/book/show/7327624-th...
# 2                  2009.0  https://www.goodreads.com/book/show/6066819-be...
# 3                     NaN  https://www.goodreads.com/book/show/287140.Run...
# 4                  2006.0  https://www.goodreads.com/book/show/287141.The...
# ...                   ...                                                ...
# 1216067            2002.0  https://www.goodreads.com/book/show/331839.Jac...
# 1216068            2007.0  https://www.goodreads.com/book/show/2685097-th...
# 1216069            2015.0  https://www.goodreads.com/book/show/26168430-s...
# 1216070            1996.0  https://www.goodreads.com/book/show/2342551.Th...
# 1216071            2014.0  https://www.goodreads.com/book/show/22017381-1...
#
#                                                  image_url   book_id  \
# 0        https://images.gr-assets.com/books/1310220028m...   5333265
# 1        https://images.gr-assets.com/books/1304100136m...   7327624
# 2        https://s.gr-assets.com/assets/nophoto/book/11...   6066819
# 3        https://images.gr-assets.com/books/1413219371m...    287140
# 4        https://s.gr-assets.com/assets/nophoto/book/11...    287141
# ...                                                    ...       ...
# 1216067  https://s.gr-assets.com/assets/nophoto/book/11...    331839
# 1216068  https://s.gr-assets.com/assets/nophoto/book/11...   2685097
# 1216069  https://images.gr-assets.com/books/1440592011m...  26168430
# 1216070  https://s.gr-assets.com/assets/nophoto/book/11...   2342551
# 1216071  https://images.gr-assets.com/books/1398621236m...  22017381
#
#          ratings_count     work_id  \
# 0                  3.0   5400751.0
# 1                140.0   8948723.0
# 2              51184.0   6243154.0
# 3                 15.0    278577.0
# 4                 46.0    278578.0
# ...                ...         ...
# 1216067           18.0  25313618.0
# 1216068          112.0   2710420.0
# 1216069            6.0  46130263.0
# 1216070           36.0   2349247.0
# 1216071           70.0  41332799.0
#
#                                                      title  top_genre  \
# 0                              W.C. Fields: A Life on Film          p
# 1        The Unschooled Wizard (Sun Wolf and Starhawk, ...    fantasy
# 2                                     Best Friends Forever  chick-lit
# 3        Runic Astrology: Starcraft and Timekeeping in ...      runes
# 4                            The Aeneid for Boys and Girls    history
# ...                                                    ...        ...
# 1216067     Jacqueline Kennedy Onassis: Friend of the Arts  biography
# 1216068                   The Spaniard's Blackmailed Bride  harlequin
# 1216069                Sherlock Holmes and the July Crisis    mystery
# 1216070           The Children's Classic Poetry Collection     poetry
# 1216071          101 Nights: Volume One (101 Nights, #1-3)    erotica
#
#                 author_name
# 0          Ronald J. Fields
# 1            Barbara Hambly
# 2           Jennifer Weiner
# 3             Nigel Pennick
# 4          Alfred J. Church
# ...                     ...
# 1216067    Beatrice Gormley
# 1216068         Trish Morey
# 1216069  Arthur Conan Doyle
# 1216070       Nicola Baxter
# 1216071          S.E. Reign
#
# [1216072 rows x 28 columns]

# %%
total_df.to_csv('records/cleaned_goodreads_books.csv')

# %%
total_df.keys()
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'isbn',
#        'text_reviews_count', 'series', 'language_code', 'popular_shelves',
#        'asin', 'average_rating', 'similar_books', 'description', 'format',
#        'link', 'authors', 'publisher', 'num_pages', 'isbn13',
#        'publication_month', 'publication_year', 'url', 'image_url', 'book_id',
#        'ratings_count', 'work_id', 'title', 'top_genre', 'author_name'],
#       dtype='object')

# %%
graph_df = total_df[['title',
                    'author_name',
                    'top_genre',
                    'publisher',
                    'publication_year',
                    'format',
                    'num_pages',
                    'average_rating',
                    'ratings_count',
                    'text_reviews_count',
                    'description',
                   ]]

# %%
graph_df['publication_year'] = [g if g < 2021 else 1950 for g in graph_df['publication_year']]

# %%
graph_df.to_csv('records/to_graph.csv')
